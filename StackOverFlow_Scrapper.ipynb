# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
# Set the tag you desire to scrape
tag = "artificial-intelligence"

# Set the base URL for the API
base_url = "https://api.stackexchange.com/2.3/"

# Set the parameters for the request
params = {
    "site": "stackoverflow",
    "tagged": tag,
    "filter": "withbody",
    "pagesize": 100
}

# Make the request to the API
response = requests.get(f"{base_url}questions", params=params)

# Get the JSON data from the response
data = response.json()

# Loop through the questions and print the titles
for question in data["items"]:
    print(question["title"])
# Out:
# About default boxes in SSD model
# How can I integrate python into my javascript code?
# Using Stockfish Chess AI in Unity
# How to connect HTML button to pyhton ai code(for ex Jarvis code)
# Why am I getting an &#39;method&#39; is not iterable error?
# Google Coral Dev Board not picking up Sound / Input
# in &lt;module&gt; class mlp
# question about AI chatbots how are neural networks used to make it A I
# error: OpenCV(4.6.0) /io/opencv/modules/imgproc/src/color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function &#39;cvtColor&#39;
# How to execute a trained model with python?
# why it says I don&#39;t have admin privilage to install chatterbot?
# Python module DeepImageSearch gives ResourceExhaustedError for multiple searches
# How do you finetune an xGBoost model the correct way?
# Is there a maximum sequence length for the output of a transformer?
# GitHub Copilot could not connect to server
# Autoencoder for dimensionality reduction of binary dataset for clustering
# Markov Decsision Process: Implmenting Q Value Problem
# How to make an algorithm to detect unique objects
# Markov Descion Process: Computing the Q Value Question
# ModuleNotFoundError: no module named &#39;transformers&#39;
# How do I change the shape of a PrefetchDataset in tensorflow
# raise ValueError(&quot;optimizer got an empty parameter list&quot;)
# module &#39;keras.engine&#39; has no attribute &#39;Layer&#39;
# finding the difference between these two images using AI?
# HuggingFace BART Fine-Tuning - What Are the Input/Output Key Names?
# Pytorch runtime not included when project is built as a jar
# I want to make an AI text classifier using OpenAI API, based on GPT2 but i cannot find the API documentation for the GPT2
# Install VSCode on jetsonNX
# lyric search algorithm:prompt to real lyric
# Is it possible to extract only invoice number from text in which invoice number&#39;s format is unknown and anything?
# I want to train a ML model to generate hashtags from a sentence using Tensor flow, how to do it in Nodejs?
# What is the definition of &quot;Desired Maturity Level of AI in Software development&quot; what is roadmap or future look like
# What is the right way to test a program (AI and neural network on FANN) for a game of tic-tac-toe?
# YOLOV5 running on mac
# How do I get Xcode to select a button, Not a human
# AI good practices in combining tasks?
# Train Open Pose with custom data
# How can we convert a Python script in to Matlab code?
# Need your insights from ML/AI experts and fellows
# Open AI GPT-3 model returns bad results via API but works fine in the OpenAI Playground
# Generate possible response when using chatbot powered by chat GPT
# Binary Classification in Neural Network
# what is the difference nn.Embedding and nn.Linear
# Monte Carlo Tree Search : infinite loop
# Good graphs to get out of an AI model
# What is a real life problem that could be solved using search algorithms, that involve a dataset?
# Meta learning with variable-sized support set
# Trained model not loading using pickle module
# How to merge Laravel to AI Model
# How can i build L Layer Model?
# ChatGPT + Telegram bot - Responses are not related to the prompt
# debug a python alexa type little ai
# Where can I find some information about Document AI?
# AttributeError: &#39;ArtistList&#39; object has no attribute &#39;pop&#39;
# Python Error in Backpropagation Function, error: ValueError: operands could not be broadcast together with shapes (4,3) (4,10)
# Teaching the model on more than one dataframe/dataset
# why does the python code doesnt run fully
# Adding a Hugging Face model in a mobile app
# I have created an nlg model and trained this is my first time build an nlg model so i do i use this nlg model for chatbot and import it
# How to choose number of hidden layers and nodes in neural network?
# Resampled data Does not show any value for target class after applying SMOTE
# would this be a more efficient method to do object detection, it calls for 2 networks a basic shapes network and a classification network?
# is there a way to train an ai in unity using ml agents and in a built game
# Input 0 of layer &quot;sequential&quot; is incompatible with the layer: expected shape=(None, 300, 300, 3), found shape=(300, 300, 3)
# Jarvis ai as default
# Python &quot;speech_recognition&quot; library throwing error ``audio_data`` must be audio data with the following audio
# Can i incorporate conditions into a CNN?
# Detect pictures with Pillow in python
# Sklearn NLP Classification with prefered features
# To Search over large text Database, what should be the approach?
# Keras AI model giving errors about shape
# Does reducing the action space in a multi-armed bandit improve performance?
# Can I rescale or resize a 3D model that was created from a set of images?
# AI algorithm for adjust percentages and constant coefficients values
# I am Trying to fit in my data into a model
# What AI technology is the right one to digest contents on webpages and convert them to queryable summaries
# Is LSTM suitable for forecasting stocks trend?
# Why is conversation_memory not being recognized by the OpenAI API (&quot;InvalidRequestError: Unrecognized request argument supplied&quot;)?
# When we do uniform cost search, do we need to know where the destination or goal state is?
# AttributeError: type object &#39;sklearn.tree._criterion.array&#39; has no attribute &#39;__reduce_cython__&#39;
# Is GPT-3 a model or a framework?
# Stockfish engine in flutter
# Training a model to extract information from a document
# Why is my loss function increasing with each epoch?
# minimax function for Tic Tac Toe not behaving correctly (javascript)
# How do I create a question answering system using BERT / RoBERTa which answers based on a novel it&#39;s trained on
# Is YOLO-v7 actually better than the previous versions?
# &quot;FFMPEG Binary Not Found&quot; Python
# Neural Network questions
# I want to create an app to predict a certain result based on some past results
# where to store decision trees and multiple regression models?
# Is it possible to handle intermediate state transitions caused by a single action in reinforcement learning?
# import error: DLL load failed while importing _imaging: The specified module could not be found
# How to fix this exploding gradient in Multivariate Linear Regression?
# how to fix when chatbot hangs
# Cross-Validation, Bias and Varience of a machine learning algorithm issues
# Curiosity, Artificial recognition without neural networks
# AIML Combining the Topic and Learn Commands
# FutureWarning: Automatic reindexing on DataFrame vs Series comparisons is deprecated and will raise ValueError in a future version&quot; using ai in bot
# Loading GPU trained RPPO on CPU (sb3contrib)
