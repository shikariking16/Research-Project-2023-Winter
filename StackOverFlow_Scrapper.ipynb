# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
# Set the tag you desire to scrape
tag = "artificial-intelligence"

# Set the base URL for the API
base_url = "https://api.stackexchange.com/2.3/"

# Set the parameters for the request
params = {
    "site": "stackoverflow",
    "tagged": tag,
    "filter": "withbody",
    "pagesize": 100
}

# Make the request to the API
response = requests.get(f"{base_url}questions", params=params)

# Get the JSON data from the response
data = response.json()

# Loop through the questions and print the titles
for question in data["items"]:
    print(question["title"])
# Out:
# How to create AI Images (Midjourney) by code?
# take audio input if user saying command else recognize that the user is quiet and terminate the audio input loop/ listening from microphone
# Teach ML-Model with raw measurement data
# Running DetectGPT locally with Python
# Search engine for local Images on Smartphone
# Unable to update a numeric counter in Jason Agent Belief
# Is there a way to contact build expert system in flutter app
# Facing performance issue with cosine similarity on large dataset
# cannot import name &#39;ChatAction&#39; from &#39;telegram&#39; (/usr/local/lib/python3.9/dist-packages/telegram/__init__.py)
# Can you rename an ONNX model with Java
# How to improve the performance of a neural network/surrogate model of a simple dynamic system trained on multiple datasets?
# Computing file uniqueness
# Using a trained neural network model in a fortran code
# I am having a logic error in my facial expression recognising program
# Python Flask application is not triggering my emails on IIS Server , if there is long gap between the scheduled time
# Solving the goat, the wolf and the cabbage problem using A* search
# What does a KeyError: &lt;bound method &gt; mean and how do I fix it?
# Are there any technologies that can integrate with Android Studio to let me take a photo and identify an animal?
# PHP, MySQL Sorting by user interaction
# Tensorflow giving same output for different input, how to fix that?
# I wanted to create the array below, but for some reason it gives an error.The array itself was created using numpy
# PyTorch Reinforcment Learning Model learning the wrong thing
# how to separate a text string obtained by ocr
# Deep Reinforcement learning with complex hidden networks
# Python How to fuse road segmentation data from an image to AOA data(distance, angle)
# What should I do to be a deep learning framework development engineer?
# Creating a Smart Chatbot for Continuous Conversation with Context-based Answer Extraction?
# BFS and DFS implementations - Suggestions and improvements
# Use AI models with python scripts in applications?
# OpenAi&#39;s API-related issues
# How to create/genrate pptx or pdf file in flutter app
# Can&#39;t set the attribute &quot;trainable_weights&quot;, likely because it conflicts with an existing read-only @property of the object. Choose a different name
# Flying dji tello with python : How to map a room?
# How can i track the bouncing point of sthe ball in a real time video?
# How to deal with stack expects each tensor to be equal size eror while fine tuning a model
# Microsoft Syntex not triggering after power automate saved documents into a library
# Keras Conv2D layer has different output when using AWS Sagemaker
# How can I generate images just by inputting a vector into an AI model?
# I&#39;m searching for projects like d-id but open source
# How can i prevent a tensorflow model from giving me inf as a loss value whilst training with more than 17 data pairs
# Where can I find a lot of data to feed it an artificial intelligence?
# How can i make my chess bot iterate faster and not print out &quot;black&quot; to the terminal?
# As a developer, how would you expect an IDE-integrated AI to help you build software?
# I want to develop an AI but have no idea how to do it
# Why my cnn model predict same output and overfit
# How do I optimize the convertion of AI using NEAT Library - Neural Network?
# Algorithm for evaluating chess positions with custom pieces and different board shapes
# Bidirectional Search for Multiple Goal States
# html, js css, json chatbot for recipes in norwegian
# Can I call a process from a function?
# Unity C# Node or Waypoint system?
# Can anyone tell me if I could add the github copilot type feature on my personal code editor?
# BAM(Bidirectional Associative Memory)
# Neural Network using only python does not work with too many inputs
# ValueError: Expected input batch_size (3) to match target batch_size (9762)
# I am trying to scrape the table from the website &#39;https://www.moneycontrol.com/stocks/histstock.php?classic=true&#39; using Scrapy
# Candidate Recommendation System
# Need some advice for my idea of &quot;Sketch to design&quot; project
# RuntimeError: shape &#39;[640, 768]&#39; is invalid for input of size 269337 stable-diffusion-webui wha
# A function that determines if the empty list is part of a clause set
# Detecting anomalous sinusoidal pattern in a timeseries dataframe
# I want to make an AI text classifier using OpenAI API, based on GPT2 but i cannot find the API documentation for the GPT2
# Ways to speed up array operations in JS without third part libraries?
# Autoencoder for dimensionality reduction of binary dataset for clustering
# What is the best ML or deep learning algorithm that can be used for prioritizing and de-prioritizing a set of instances, based on parameters provided?
# Is there any activation function for complex valued networks in pytorch2?
# Alphazero probabilities vector
# How to calculate the synchronization score of two tree parity machine?
# Sliding window input (image sequence) for convolutional neural network
# C++ Neural Network Implementation for MNIST Not Working
# In an Connect 4 AI how can I minimize time running while maximizing &quot;intelligence&quot;?
# Lip Syncing Audio to A 2D Cartoon Avatar
# module &#39;keras.engine&#39; has no attribute &#39;Layer&#39;
# Natural Language Processeing
# Why my discord bot only answers with an uncomplete answer with the OpenAI API?
# wishMe() takes 0 positional arguments but 1 was given
# Adapting Vision Transformer for Regression: What to do with Class Tokens?
# What repo to use to run Stable Diffusion 2.1 locally in Python?
# Precious Advices About AI-supported Audio Classification Model
# How can I stream in a Vercel Serverless function? It&#39;s working in local, but not once deployed
# Why is there an error that says, &quot;No module named pywintypes&quot; when I run this code to make an AI Assistant?
# Any good modern world problem solving ideas?
# Training data for question-answering with model from huggingface or any other open-source
# How to convert YOLO annotations (.txt) to labelme?
# Beginner PyTorch - RuntimeError: shape &#39;[16, 400]&#39; is invalid for input of size 9600
# How to train Azure Form Recognizer to recognize a optional field?
# I have developed a software for nlp but it always returns the same output
# Limiting Watson Assistant user response to ONLY Numbers - No text allowed
# MiniMax algorithm tic-tac-toe in C explanation
# Is there a need to create a cluster on Databricks if I need to use the workspace as just the model registry using MLFlow
# Android: about monitor actions happened on UI layers as well as API call in log
# [Pytorch]Error when using DistributedDataParallel in the broadcasting stage of initialization
# Wandb Sweep tuning define output directory
# OpenAI GPT-3 API: Why am I getting different completions on Playground vs. the API?
# OpenAI GPT-3 API error: &quot;InvalidRequestError: Unrecognized request argument supplied&quot;
# How to use FNet in encoder of EncoderDecoderModel models of huggingface(transformers) library?
# AttributeError: &#39;ArtistList&#39; object has no attribute &#39;pop&#39;
# How do I input 3-dimensional array sequence?
# Reading Sudokus from text file and applying backtracking
# Monte-carlo search tree with hidden information
