# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
# Set the tag you desire to scrape
tag = "artificial-intelligence"
# Set the base URL for the API
base_url = "https://api.stackexchange.com/2.3/"

# Set the parameters for the request
params = {
    "site": "stackoverflow",
    "tagged": tag,
    "filter": "withbody",
    "pagesize": 100
}

# Make the request to the API
response = requests.get(f"{base_url}questions", params=params)

# Get the JSON data from the response
data = response.json()

# Loop through the questions and print the titles
for question in data["items"]:
    print(question["title"])
# Out:
# why it returns me that the index is out of range while I try to sum up the matrix?
# How to start and stop the same loop by the keyboard
# Python TypeError: &#39;set&#39; object is not subscriptable
# Indexing on ndarrays result in wrong shape
# Highlight polygons incident at a vertex
# How to plot density of states (DOS) using histogram
# R^2 value negative when running a Random Forest Algoritm
# Python: Nonlinear optimisation with Gekko
# How to create a container within a python script?
# Pyodbc Microsoft Access database doesn&#39;t work anymore (Unable to open registry key)
# Using package to perform a rolling window function with a group by
# How to combine list to a nested list
# Replace missing values with the value of the column with the minimum sum of differences
# Import OpenCV on jupyter notebook
# Sorting 2D numpy array by column index Python
# I am getting a variable that&#39;s not set to none yet I am getting an error if &quot;NoneType&quot;
# Develop Multitask GP Regression with learnable parameters
# Why below apache Beam code return different output?
# Python and Nvim: How to activate both global and local virtual env at the same time
# Calculating xarray xclim climate indices on a rolling window (rather than fixed window) basis
# Failure to install old versions of transformers in colab
# How to calculate cosine similarity?
# Split a string with only capitalized letters and concatenated words
# using np.exp() to convert column in pandas DF
# How to QUICKLY batch scan video files to check for integrity (corrupt / valid)
# cropping voronoi diagram to a bounded box using CGAL in python
# How to pass coordinates from lists to multiple stepper motors at the same time, not in sequence?
# Python: unsupported operand type(s) for +=: &#39;int&#39; and &#39;NoneType
# NC file having different groups - need to extract selected one variable from all the groups
# Create group having Percentage diff &lt;=30%
# Why does coverage.py not report a for loop where the body is not skipped when running it with --branch?
# installed python3 module not found runtime
# get a string between each / within string
# RP2040-Zero Not Blinking
# Taking specific data from .txt and sorting it into an excel or csv file through Python
# My POST method can&#39;t receive data (flask api)
# How to fix Python pip install openai error: subprocess-exited-with-error
# find bubble text using opencv
# How to upgrade pandas 2.0rc in VSCode
# How to configure &#39;TLS1.2 only&#39; in OpenSSL 1.0.2 config file?
# Google Aps Script TypeError: Cannot read properties of undefined (reading &#39;message&#39;)
# FileNotFoundError: [Errno 2] No such file or directory: &#39;movies.csv&#39;
# How to convert Neomodel relationship data into JSON for passing it to Cytoscape.js
# &#39;Length of values does not match length of index&#39; on a groupby
# Problem with DataFrame_Image No such file or directory: ...\\AppData\\Local\\Temp\\tmpm56n0wp6\\temp.png
# Open Jupyter notebook without render images and without popolating dataframes - safe mode loading preventing out of memory state
# (eval):10: unmatched | conda active error on iTerm, Mac M1 Big Sur
# Unable to get data from Scrapy API
# Clicking on the correct option from a given list of options in Selenium Python
# How I may execute PYTEST based tests on different OSes in parallel
# How to use tessedit_write_images with pytesseract?
# I am unable to print the result of the game with scores
# Python re and regex not matching my patterns
# Can I perform an operation in bulk excel files using python?
# polars aggregate string column into sketch or hyperloglog object
# Elbow method will not output an elbow as a curve
# AutoModelForQuestionAnswering: ValueError: too many values to unpack (expected 2)
# How to include a point of a float in the output?
# Merging two Pandas DataFrames based on the sequential order of two columns
# How to upload image in django without using django forms
# Hey, so im creating a APi which is integrated with a Discord bot. However when i wanted to send a message to a channel it gave me a runtime error
# KeyError: False; Pandas dataframe error when creating list from dataframe columns
# Detect rows where uniqueness is not given in polars
# Using &#39;_&#39; variable in &#39;if&#39; statements
# polars aggregate array[string] column into set[str]
# Integrating with python&#39;s quad function over multiple values using vectors (instead of for loops) with changing bounds
# Celery Groups: How to create a group of already running tasks?
# Telegram through telethon timeouts on my server. FloodWaitError keeps multiplying on a script that works fine on local
# finding n largest differences between two lists
# How do I access the length of a square array in Python?
# i just got an empty list when i print soup list as given below
# &quot;Import Error: NumPy not found&quot; when importing wx.lib.py
# Python multiprocessing within class: OSError: [WinError 87] The parameter is incorrect
# Function to store sg.Text() values in an Excel worksheet? (Python)
# Split a string &quot;aabbcc&quot; -&gt; [&quot;aa&quot;, &quot;bb&quot;, &quot;cc&quot;] without re.split
# Py-solc and solidity imports
# Of Healthy Programming Practices
# python 3 using list items to issue Cisco IOS command
# Loading a HuggingFace model on multiple GPUs using model parallelism for inference
# Trouble importing Numpy into Grass GIS 7.0 on Windows 10
# Using numpy arrays with lpsolve?
# How to fix or help me understand the issue of a broken firebird database
# How to compare two files byte per byte, but also account for missing bytes?
# How can I position my kivy app window in the right bottom corner
# How to reliably check from Python script code if just created directory exist?
# How should I type my sqlite connection and cursor in a python class before I provide meaningful values?
# How to generate a 3D surface function to fit given 3D points and interpolate 3rd coordinate if I have other 3 coordinates
# Python windrose produces wind rose with cut-out sector
# convert 2 digits year to 20th century only from the end of string
# return default if pandas dataframe.loc location doesn&#39;t exist
# List comprehension with an accumulator
# Python SQLite math functions (no such function: SQRT)
# Snowflake: Query in Snowflake UI returns different number of rows than the same query in Snowpark with Python
# Export (but not save to) an audio file in PyDub?
# Pandas Datetime Calculation Output
# Getting variable constraint value
# Group Rows based on an overlapping start and end time (Hockey Data)
# feature crossing in pandas
# Compare dictionaries to check if they are equal or if they go from empty to having a value
# Converting pandas tuple columns to multiindex
